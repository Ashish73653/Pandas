# %% [markdown]
# ## Read CSV

# %%
import pandas as pd

csv_1 = pd.read_csv("F:\\Jupyter Noteebook\\Pandas\\MOCK_DATA.csv")
csv_1
# Out:
#    first_name     last_name                              email       gender  \
# 0      Archer        Nowick                   anowick0@msu.edu         Male
# 1        Ring      Sambedge               rsambedge1@google.ru  Genderfluid
# 2     Aindrea      Belhomme              abelhomme2@hao123.com  Genderqueer
# 3      Lilith         Ayres                  layres3@google.it       Female
# 4       Emlen   Banishevitz  ebanishevitz4@creativecommons.org         Male
# 5    Kimberli       Newbatt            knewbatt5@csmonitor.com       Female
# 6       Stace        Follen                  sfollen6@ebay.com       Female
# 7     Thomasa       Coarser            tcoarser7@shinystat.com       Female
# 8       Davon         Acedo                     dacedo8@si.edu         Male
# 9     Rosanna          Yapp             ryapp9@accuweather.com       Female
# 10     Travus      Beachamp              tbeachampa@jalbum.net         Male
# ...

# %%
## For selecting rows upto some number
csv_2 = pd.read_csv("F:\\Jupyter Noteebook\\Pandas\\MOCK_DATA.csv",nrows=5)
csv_2
# Out:
#   first_name    last_name                              email       gender  \
# 0     Archer       Nowick                   anowick0@msu.edu         Male
# 1       Ring     Sambedge               rsambedge1@google.ru  Genderfluid
# 2    Aindrea     Belhomme              abelhomme2@hao123.com  Genderqueer
# 3     Lilith        Ayres                  layres3@google.it       Female
# 4      Emlen  Banishevitz  ebanishevitz4@creativecommons.org         Male
#
#         ip_address
# 0     96.62.232.54
# 1   131.26.238.196
# 2    87.180.180.39
# 3    38.10.131.255
# 4  113.166.201.156

# %%
## for selectimg particular columns
csv_3 = pd.read_csv("F:\\Jupyter Noteebook\\Pandas\\MOCK_DATA.csv",usecols=["first_name","email","ip_address"])
csv_3
# Out:
#    first_name                              email       ip_address
# 0      Archer                   anowick0@msu.edu     96.62.232.54
# 1        Ring               rsambedge1@google.ru   131.26.238.196
# 2     Aindrea              abelhomme2@hao123.com    87.180.180.39
# 3      Lilith                  layres3@google.it    38.10.131.255
# 4       Emlen  ebanishevitz4@creativecommons.org  113.166.201.156
# 5    Kimberli            knewbatt5@csmonitor.com      54.22.147.4
# 6       Stace                  sfollen6@ebay.com   235.221.68.197
# 7     Thomasa            tcoarser7@shinystat.com      53.40.142.3
# 8       Davon                     dacedo8@si.edu  127.153.187.188
# 9     Rosanna             ryapp9@accuweather.com  229.231.121.185
# 10     Travus              tbeachampa@jalbum.net     32.230.60.12
# 11   Harmonie              hmooreedb@yahoo.co.jp      17.45.74.89
# 12      Karon          kcastagnac@wikispaces.com      8.7.156.213
# ...

# %%
## for skipping some rows
csv_4 = pd.read_csv("F:\\Jupyter Noteebook\\Pandas\\MOCK_DATA.csv",skiprows=[31,32])
csv_4
# Out:
#    first_name     last_name                              email       gender  \
# 0      Archer        Nowick                   anowick0@msu.edu         Male
# 1        Ring      Sambedge               rsambedge1@google.ru  Genderfluid
# 2     Aindrea      Belhomme              abelhomme2@hao123.com  Genderqueer
# 3      Lilith         Ayres                  layres3@google.it       Female
# 4       Emlen   Banishevitz  ebanishevitz4@creativecommons.org         Male
# 5    Kimberli       Newbatt            knewbatt5@csmonitor.com       Female
# 6       Stace        Follen                  sfollen6@ebay.com       Female
# 7     Thomasa       Coarser            tcoarser7@shinystat.com       Female
# 8       Davon         Acedo                     dacedo8@si.edu         Male
# 9     Rosanna          Yapp             ryapp9@accuweather.com       Female
# 10     Travus      Beachamp              tbeachampa@jalbum.net         Male
# ...
